# %%
# Um exercício rápido sobre regressão linear
# O programa cria um modelo de regressão linear para prever o investimento inicial necessário de uma franquia a partir de sua taxa anual (cobrada pelo franqueador)
# A base de dados foi oferecida pelo curso de Data Science a qual conclui

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Carregando a base de dados utilizando pandas
base = pd.read_csv('slr12.csv', sep=";")

# %%
# Inicialmente é utilizado o shape para verificar as dimensões da base de dados. 36 instâncias e 2 colunas
base.shape
# Out:
# (36, 2)

# %%
# Chamada simples da base apenas para verificar a forma que a mesma é organizada
base
# Out:
#     FrqAnual  CusInic
# 0       1000     1050
# 1       1125     1150
# 2       1087     1213
# 3       1070     1275
# 4       1100     1300
# 5       1150     1300
# 6       1250     1400
# 7       1150     1400
# 8       1100     1250
# 9       1350     1830
# 10      1275     1350
# 11      1375     1450
# 12      1175     1300
# 13      1200     1300
# 14      1175     1275
# 15      1300     1375
# 16      1260     1285
# 17      1330     1400
# 18      1325     1400
# 19      1200     1285
# 20      1225     1275
# 21      1090     1135
# 22      1075     1250
# 23      1080     1275
# 24      1080     1150
# 25      1180     1250
# 26      1225     1275
# 27      1175     1225
# 28      1250     1280
# 29      1250     1300
# 30       750     1250
# 31      1125     1175
# 32       700     1300
# 33       900     1250
# 34       900     1300
# 35       850     1200

# %%
# Verifcação se existe algum valor nulo
base.isnull().sum()
# Out:
# FrqAnual    0
# CusInic     0
# dtype: int64

# %%
# Uso do describe para  compreender melhor os valores de cada coluna
base.describe()
# Out:
#           FrqAnual      CusInic
# count    36.000000    36.000000
# mean   1134.777778  1291.055556
# std     158.583211   124.058038
# min     700.000000  1050.000000
# 25%    1080.000000  1250.000000
# 50%    1162.500000  1277.500000
# 75%    1250.000000  1300.000000
# max    1375.000000  1830.000000

# %%
# Definição das variáveis X e Y
# X  é a variável independente (FrqAnual) e Y é a variável dependente (CusInic)
# É passado os valores das respectivas colunas
x = base['FrqAnual'].values
y = base['CusInic'].values

# %%
# Uso do numpy para calcular a correlação entre as variáveis
corr = np.corrcoef(x, y)
# Chama a variável verficando o valor baixo da correlação
corr
# Out:
# array([[1.        , 0.47700725],
#        [0.47700725, 1.        ]])

# %%
# Para a criação do modelo é feito um reshape da variável para formato de matriz de coluna única
x = x.reshape(-1, 1) 
x
# Out:
# array([[1000],
#        [1125],
#        [1087],
#        [1070],
#        [1100],
#        [1150],
#        [1250],
#        [1150],
#        [1100],
#        [1350],
#        [1275],
#        [1375],
#        [1175],
#        [1200],
#        [1175],
#        [1300],
#        [1260],
#        [1330],
#        [1325],
#        [1200],
#        [1225],
#        [1090],
#        [1075],
#        [1080],
#        [1080],
#        [1180],
#        [1225],
#        [1175],
#        [1250],
#        [1250],
#        [ 750],
#        [1125],
#        [ 700],
#        [ 900],
#        [ 900],
#        [ 850]], dtype=int64)

# %%
# Criação do modelo 
modelo = LinearRegression()
# Treinamento do modelo utilizando fit
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
# Gera um gráfico de dispersão verificando os pontos reais da base de dados e as previsões do modelo

plt.scatter(x, y)
plt.plot(x, modelo.predict(X), color = 'red')
plt.title('Pontos reais X Previsões')
# Out:
# Text(0.5, 1.0, 'Pontos reais X Previsões')

# %%
# Testes de previsões 
#valor anual da franquina
valor_anual = 2000
modelo.predict([[valor_anual]])
# Out:
# array([1613.92009412])

# %%
valor_anual = 1500
modelo.predict([[valor_anual]])
# Out:
# array([1427.34112616])
